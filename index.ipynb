# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

from plotly.graph_objs import Scatter, Figure, Layout


import pandas as pd

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import plotly
plotly.__version__
# Out:
# '2.0.10'

# %%
# load csv with all weight percent chem data from all samples
df = pd.read_csv("tidy_merged4.csv")

# %%
df.describe()
# Out:
#          NoParenSol  Silicon_Oxide(SiO2)  RMSE_Silicon_Oxide  \
# count  10590.000000         10590.000000        10590.000000
# mean     784.551464            47.599500            5.228772
# std      476.173274            11.369453            0.408774
# min       13.000000             0.000000            4.900000
# 25%      335.000000            42.900000            5.000000
# 50%      732.000000            46.800000            5.100000
# 75%     1245.000000            52.300000            5.300000
# max     1900.000000            96.300000            7.100000
#
#        Silicon_Oxide_StDEV  Titanium_Oxide(TiO2)  RMSE_Titanium_Oxide  \
# count         10590.000000          10590.000000         10590.000000
# mean              1.161549              1.153663             0.563500
# std               1.111138              2.612929             1.231637
# min               0.000000              0.000000             0.200000
# ...

# %%
data = [
    go.Parcoords(
        line = dict(color = df['NoParenSol'],
                   colorscale = 'Jet',
                   showscale = True,
                   reversescale = True,
                   cmin = 0,
                   cmax = 2000),
        dimensions = list([
            dict(range = [0,100],
                label = 'SiO2', values = df['Silicon_Oxide(SiO2)']),
            dict(range = [0,100],
                label = 'TiO2', values = df['Titanium_Oxide(TiO2)']),
            dict(range = [0,100],
                label = 'AI2O3', values = df['Aluminum_Oxide(AI2O3)']),
            dict(range = [0,100],
                label = 'Na2O', values = df['Sodium_Oxide(Na2O)']),
            dict(range = [0,100],
                label = 'K2O', values = df['Potassium_Oxide(K2O)']),
            dict(range = [0,100],
                label = 'CaO', values = df['Calcium_Oxide(CaO)']),
            dict(range = [0,150],
                label = 'Sum_of_Oxides', values = df['Sum_of_Oxides']),
            dict(range = [0,10],
                label = 'Distance_Rover_m', values = df['Distance_Rover_m']),
            dict(range = [0,100000000000000],
                label = 'Spectrum_Total', values = df['Spectrum_Total']),
            dict(range = [0,2000],
                label = 'NoParenSol', values = df['NoParenSol'])

        ])
    )
]

layout = go.Layout(
    plot_bgcolor = '#E5E5E5',
    paper_bgcolor = '#E5E5E5'
)

iplot(data)
# Out:
# <div id="69caa9c8-c712-4ab8-badc-c4aea42045cf" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("69caa9c8-c712-4ab8-badc-c4aea42045cf", [{"type": "parcoords", "dimensions": [{"range": [0, 100], "label": "SiO2", "values": [45.8, 40.0, 47.4, 45.7, 74.1, 54.6, 51.5, 48.3, 45.6, 50.0, 51.3, 50.3, 53.8, 53.1, 47.7, 45.4, 47.2, 51.2, 46.9, 49.7, 56.2, 54.0, 46.4, 54.3, 53.3, 53.8, 39.4, 63.4, 72.3, 61.1, 44.7, 54.4, 50.3, 55.0, 47.8, 54.7, 39.3, 39.9, 44.7, 49.7, 42.2, 45.6, 42.7, 42.5, 51.2, 52.5, 48.7, 51.6, 49.8, 44.3, 42.9, 46.6, 44.2, 41.3, 53.5, 54.5, 45.1, 59.3, 51.9, 43.0, 55.2, 60.5, 66.1, 50.9, 53.9, 43.0, 50.6, 46.0, 55.6, 52.1, 52.7, 40.5, 55.0, 48.9, 36.5, 53.0, 51.9, 46.2, 50.3, 41.0, 51.1, 43.4, 55.0, 41.4, 46.8, 41.0, 44.6, 53.5, 49.7, 46.9, 48.2, 53.7, 42.9, 42.8, 44.3, 43.7, 45.3, 42.9, 4
# ...
